# %%
import pandas as pd
df = pd.read_csv('dataset.csv')
print(df.head())
# Out:
#    Feature1  Feature2  Feature3  Target
# 0       5.1       3.5       1.4       0
# 1       4.9       3.0       1.4       0
# 2       6.2       2.8       4.8       1
# 3       5.9       3.2       5.1       2
# 4       6.7       3.1       5.6       2
